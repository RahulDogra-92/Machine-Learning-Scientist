# %%
import os 
import random2
from math import floor
import glob, os
import pdfplumber
import torch
import spacy
import re
from bs4 import BeautifulSoup
from tqdm import tqdm
from spacy.tokens import DocBin
from tqdm import tqdm
import json
import numpy as np
import pandas as pd
import os

# %%
class random:
    
    def __init__(self, datadir):
        self.datadir = datadir
        
    
    def get_file_list_from_dir(self):
        all_files = os.listdir(os.path.abspath(self.datadir))
        self.data_files = list(filter(lambda file: file.endswith('.json'), all_files))
        return self.data_files

    def randomize_files(self):
        self.shuffled = random2.sample(self.data_files, len(self.data_files))
        return self.shuffled

    def get_training_and_testing_sets(self):
        split = 0.8
        split_index = floor(len( self.shuffled) * split)
        training =  self.shuffled[:split_index]
        testing =  self.shuffled[split_index:]
        return training, testing

        
if __name__ == "__main__":
    
    obj = random('D:\\266')
    list_of_files = obj.get_file_list_from_dir()
    suffled_data = obj.randomize_files()
    training, testing = obj.get_training_and_testing_sets()
    print(len(training))
    print(len(testing))
# Out:
# 212
# 54

# %%
training[:5]
# Out:
# ['WORKFORCE OUTSOURCE SERVICES INC-Master Service Agreement-Consulting Agreement-10-25-2017.json',
#  'Gallagher Bassett Services, Inc.json',
#  'Wildlife Design MSA FINAL.json',
#  'DINO SOFTWARE CORPORATION-Master Service Agreement-Master Software License Agreement-12-12-2017.json',
#  '1041815-MSA-GAC-110514-123123.json']

# %%
import spacy
from spacy.tokens import DocBin
nlp1 =  spacy.blank('en')  # load a new spacy model
nlp2 =  spacy.blank('en')
db1 = DocBin() # create a DocBin object
db2 = DocBin()

# %%
os.chdir('D:\\266\\')
for filename in training:
    f = open(filename,encoding='UTF-8')
    TRAIN_DATA = json.load(f)

    for text, annot in tqdm(TRAIN_DATA['annotations']):
        doc1 = nlp1.make_doc(text) 
        ents = []
        for start, end, label in annot["entities"]:
            span = doc1.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
        doc1.ents = ents 
        db1.add(doc1)

os.chdir(r'D:\OneDrive_2022-01-12\training_data')
db1.to_disk("./train.spacy") # save the docbin object
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.29it/s]

# %%
os.chdir('D:\\266\\')
for filename in testing:
    f = open(filename,encoding='UTF-8')
    TEST_DATA = json.load(f)

    for text, annot in tqdm(TEST_DATA['annotations']):
        doc2 = nlp2.make_doc(text) 
        ents = []
        for start, end, label in annot["entities"]:
            span = doc2.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
        doc2.ents = ents 
        db2.add(doc2)

os.chdir(r'D:\OneDrive_2022-01-12\training_data')
db2.to_disk("./test.spacy") # save the docbin object
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.75it/s]

# %%
len(training)
# Out:
# 212

# %%
len(testing)
# Out:
# 54

# %%
testing
# Out:
# ['MCAFEE INC-Software License Assignment Agreement-Master Software License Agreement-06-13-2018.json',
#  'UIPATH INC-Master Software License Agreement-Master Software License Agreement-1-29-2016.json',
#  '1043429-NGA-MSA-070115-070123.json',
#  'SWLA Schedule 1_signed.json',
#  'Vurv License Agreement 122404 for SOT.json',
#  '11 DOLLAR BILL LLC-Master Service Agreement-Mirror Agreement-7-12-2018.json',
#  'CVG Data Ctr MSA Executed.json',
#  'ABBYY USA SOFTWARE HOUSE INC MSA.json',
#  'Alight Cloudator Framework MSA (100118).json',
#  'MERRILL CONSULTANTS-Master Software License Agreement-License Agreement For Mxg Software-5-05-2016.json',
#  'Chime MSA.json',
#  'Carpenter Lipps and Leland LLP-Master Agreement for Services-Master Service Agreement-04-16-2019.json',
#  'Milliman Service Agreement_040621_040524.json',
#  'Automation Anywhere_License Agreement_122118_062422.json',
# ...
